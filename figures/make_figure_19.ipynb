# %%
import matplotlib.pylab as plt
import matplotlib as mpl
import numpy as np
import h5py
from scipy.special import erf
mpl.style.use('./plotting.mplstyle')
from makeCorner import *

# %%
# Load AR results: Gaussian
Xeff_Xp_data = h5py.File("./../data/ar_Xeff_Xp_summary.hdf","r")

# %%
plot_data = {
    'Xeff_std':{'data':Xeff_Xp_data['posterior/ar_Xeff_std'][()],'plot_bounds':(0,4),'label':r'$\sigma_{\chi_\mathrm{eff}}$'},
    'Xeff_tau':{'data':np.log(Xeff_Xp_data['posterior/ar_Xeff_tau'][()]),'plot_bounds':(-3,3),'label':r'$\ln\tau_{\chi_\mathrm{eff}}$'},
    'Xp_std':{'data':Xeff_Xp_data['posterior/ar_Xp_std'][()],'plot_bounds':(0,4),'label':r'$\sigma_{\chi_\mathrm{p}}$'},
    'Xp_tau':{'data':np.log(Xeff_Xp_data['posterior/ar_Xp_tau'][()]),'plot_bounds':(-4,6),'label':r'$\ln\tau_{\chi_\mathrm{p}}$'},
    'neff':{'data':np.log10(Xeff_Xp_data['posterior/nEff_inj_per_event'][()]),'plot_bounds':(0,3),
            'label':r'$\log_{10}(N^\mathrm{inj}_\mathrm{eff}/N_\mathrm{obs})$'},
    'min_neff':{'data':Xeff_Xp_data['posterior/min_log_neff'][()],'plot_bounds':(0,2.),
                'label':r'$\mathrm{min}\log_{10}(N_\mathrm{eff}^\mathrm{samp})$'},
}

fig = plt.figure(figsize=(10,10))
plot_corner(fig,plot_data,'#3182bd')
plt.subplots_adjust(hspace=0.1,wspace=0.15)
plt.savefig('figure_19.pdf',bbox_inches='tight',dpi=200)
plt.show()
