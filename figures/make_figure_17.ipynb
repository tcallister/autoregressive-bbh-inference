# %%
import matplotlib.pylab as plt
import matplotlib as mpl
import numpy as np
import h5py
from scipy.special import erf
mpl.style.use('./plotting.mplstyle')
from makeCorner import *

# %%
# Load AR results: Redshift
z_data = h5py.File("./../data/ar_z_summary.hdf","r")

# %%
plot_data = {
    'z_std':{'data':z_data['posterior/ar_z_std'][()],'plot_bounds':(0,4),'label':r'$\sigma_z$'},
    'z_tau':{'data':np.log(z_data['posterior/ar_z_tau'][()]),'plot_bounds':(-8,8),'label':r'$\ln\tau_z$'},
    'neff':{'data':np.log10(z_data['posterior/nEff_inj_per_event'][()]),'plot_bounds':(0,2.5),
            'label':r'$\log_{10}(N^\mathrm{inj}_\mathrm{eff}/N_\mathrm{obs})$'},
    'min_neff':{'data':z_data['posterior/min_log_neff'][()],'plot_bounds':(0,3),
                'label':r'$\mathrm{min}\log_{10}(N_\mathrm{eff}^\mathrm{samp})$'},
}

fig = plt.figure(figsize=(7,7))
plot_corner(fig,plot_data,'#3182bd')
plt.subplots_adjust(hspace=0.1,wspace=0.15)
plt.savefig('figure_17.pdf',bbox_inches='tight',dpi=200)
plt.show()
